# %%
from basicTimeSeries import ARIMAModels

# %%
import pandas as pd
data = pd.read_csv("export_prices_1 - Copy11.csv")
data["date"] = pd.to_datetime(data["date"])
data.set_index("date", inplace=True)
data.head()
# Out:
#             Year Month  Volume Horticulture  (Tonnes)  \
# date
# 2007-01-01  2007   Jan                       17112.39
# 2007-02-01  2007   Feb                       18905.81
# 2007-03-01  2007   Mar                       24796.49
# 2007-04-01  2007   Apr                       22748.93
# 2007-05-01  2007   May                       22885.72
#
#             Average Horticulture (Kshs. per Tonne)  Annual Average Inflation   \
# date
# 2007-01-01                               188541.52                       6.08
# 2007-02-01                               175393.06                       5.55
# 2007-03-01                               148545.24                       4.99
# 2007-04-01                               168518.27                       4.69
# 2007-05-01                               168111.86                       4.47
#
#             Diaspora Remittances  Euro ex  Sterling Pound ex  US ex  \
# date
# 2007-01-01              40930.36    90.87             136.91  69.89
# 2007-02-01              39533.07    91.04             136.40  69.62
# 2007-03-01              48561.00    91.77             134.91  69.29
# 2007-04-01              38250.91    92.68             136.40  68.58
# 2007-05-01              41163.50    90.82             133.31  67.19
#
#             CB Deposit  CB Savings  CB Overdraft   CB Lending   Active Agents  \
# date
# 2007-01-01        4.35        1.42          14.11        13.78            307
# 2007-02-01        4.21        1.41          14.05        13.64            307
# 2007-03-01        4.19        1.43          13.95        13.56            307
# 2007-04-01        4.11        1.35          13.26        13.33            362
# 2007-05-01        4.14        1.57          13.35        13.38            447
#
#             Total Registered Mobile Money Accounts (Millions)  \
# date
# 2007-01-01                                           0.020992
# 2007-02-01                                           0.020992
# 2007-03-01                                           0.020992
# 2007-04-01                                           0.054944
# 2007-05-01                                           0.107733
#
#             Total Agent Cash in Cash Out (Volume Million)  \
# date
# 2007-01-01                                       0.021714
# 2007-02-01                                       0.021714
# 2007-03-01                                       0.021714
# 2007-04-01                                       0.070000
# 2007-05-01                                       0.150000
#
#             Total Agent Cash in Cash Out (Value KSh billions)
# date
# 2007-01-01                                           0.064391
# 2007-02-01                                           0.064391
# 2007-03-01                                           0.064391
# 2007-04-01                                           0.220896
# 2007-05-01                                           0.483709

# %%
data = data[['Volume Horticulture  (Tonnes)',
       'Average Horticulture (Kshs. per Tonne)', 'Annual Average Inflation ',
       'Diaspora Remittances', 'Euro ex', 'Sterling Pound ex', 'US ex',
       'CB Deposit', 'CB Savings', 'CB Overdraft ', 'CB Lending ',
       'Active Agents', 'Total Registered Mobile Money Accounts (Millions)',
       'Total Agent Cash in Cash Out (Volume Million)',
       'Total Agent Cash in Cash Out (Value KSh billions)']]

# %%
timeseries = ARIMAModels()
timeseries.trend_visualizations(data["Average Horticulture (Kshs. per Tonne)"])

# %%
timeseries.decomposition_plot(data["Average Horticulture (Kshs. per Tonne)"], period=12)

# %%
timeseries.correlation_function(data["Average Horticulture (Kshs. per Tonne)"], lags=15)

# %%
timeseries.stationarity_check(data)
# Out:
#     Augmented Dickey-Fuller Test on "Volume Horticulture  (Tonnes)"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.8409
#  No. Lags Chosen       = 4
#  Critical value 1%     = -3.468
#  Critical value 5%     = -2.878
#  Critical value 10%    = -2.576
#  => P-Value = 0.3603. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Average Horticulture (Kshs. per Tonne)"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.7007
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.468
#  Critical value 5%     = -2.878
#  Critical value 10%    = -2.576
#  => P-Value = 0.0041. Rejecting Null Hypothesis.
#  => Series is Stationary.
#     Augmented Dickey-Fuller Test on "Annual Average Inflation "
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.6704
#  No. Lags Chosen       = 13
#  Critical value 1%     = -3.47
#  Critical value 5%     = -2.879
#  Critical value 10%    = -2.576
#  => P-Value = 0.0793. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Diaspora Remittances"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = 2.5742
#  No. Lags Chosen       = 11
#  Critical value 1%     = -3.47
#  Critical value 5%     = -2.879
#  Critical value 10%    = -2.576
#  => P-Value = 0.9991. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Euro ex"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.6537
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.468
#  Critical value 5%     = -2.878
#  Critical value 10%    = -2.576
#  => P-Value = 0.0824. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Sterling Pound ex"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.5179
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.468
#  Critical value 5%     = -2.878
#  Critical value 10%    = -2.576
#  => P-Value = 0.1112. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "US ex"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.0702
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.468
#  Critical value 5%     = -2.878
#  Critical value 10%    = -2.576
#  => P-Value = 0.7268. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "CB Deposit"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.1023
#  No. Lags Chosen       = 6
#  Critical value 1%     = -3.469
#  Critical value 5%     = -2.878
#  Critical value 10%    = -2.576
#  => P-Value = 0.2436. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "CB Savings"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.5783
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.468
#  Critical value 5%     = -2.878
#  Critical value 10%    = -2.576
#  => P-Value = 0.4945. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "CB Overdraft "
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.8742
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.468
#  Critical value 5%     = -2.878
#  Critical value 10%    = -2.576
#  => P-Value = 0.3443. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "CB Lending "
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.0128
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.468
#  Critical value 5%     = -2.878
#  Critical value 10%    = -2.576
#  => P-Value = 0.281. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Active Agents"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = 1.5531
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.468
#  Critical value 5%     = -2.878
#  Critical value 10%    = -2.576
#  => P-Value = 0.9977. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Total Registered Mobile Money Accounts (Millions)"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -0.0595
#  No. Lags Chosen       = 9
#  Critical value 1%     = -3.469
#  Critical value 5%     = -2.879
#  Critical value 10%    = -2.576
#  => P-Value = 0.9533. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Total Agent Cash in Cash Out (Volume Million)"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = 0.5213
#  No. Lags Chosen       = 13
#  Critical value 1%     = -3.47
#  Critical value 5%     = -2.879
#  Critical value 10%    = -2.576
#  => P-Value = 0.9855. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Total Agent Cash in Cash Out (Value KSh billions)"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = 0.6789
#  No. Lags Chosen       = 12
#  Critical value 1%     = -3.47
#  Critical value 5%     = -2.879
#  Critical value 10%    = -2.576
#  => P-Value = 0.9894. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.

# %%
timeseries.stationarity_check(data["Average Horticulture (Kshs. per Tonne)"])
# Out:
# Augmented Dickey Fuller Test
#
# null-hypothesis: The data is non-stationary
# alternative-hypothesis: The data is stationary
#  -----------------------------------------------
# p-value:                = 0.004103637200194154
# test-statistic:         = -3.700677313400817
# Number of lag chosen:   = 1
# observation:            = 178
# critical-values:        = {'1%': -3.467631519151906, '5%': -2.8779183721695567, '10%': -2.575501353364474}
# maximized-criteria:     = 3814.4229822616194
# => The data is stationary. The p-value is 0.004 thus we reject the null hypothesis
#
#
# -----------------------------------------------
#  -----------------------------------------------
#
# KPSS Test for Stationarity
#
# H0: The time series data is stationary
# H1:The time series data is non-stationary
#  -----------------------------------------------
# KPSS Statistic: =0.6673600550952664
# p-value:        =0.016512722264066686
# num lags:       =8
# Critial Values:
#    10% :  =0.347
#    5% :  =0.463
#    2.5% :  =0.574
#    1% :  =0.739
# Result: The series is not stationary

# %%
train, test = timeseries.split_data(data["Volume Horticulture  (Tonnes)"])

# %%
p_values = [1,2]
q_values = [1,2]
d_values = [0,1]
timeseries.model_evaluation(train,
                            test,
                            p_values=p_values,
                            d_values=d_values,
                            q_values=q_values)
# Out:
# ARIMA(1, 0, 1) MSE=107551475.368471
# ARIMA(1, 0, 2) MSE=109145963.425870
# ARIMA(1, 1, 1) MSE=113499495.779539
# ARIMA(1, 1, 2) MSE=105736388.833744
# ARIMA(2, 0, 1) MSE=112186314.039439
# ARIMA(2, 0, 2) MSE=113348735.644304
# ARIMA(2, 1, 1) MSE=103759834.926579
# ARIMA(2, 1, 2) MSE=104841476.797629
# Best ARIMA(2, 1, 1) MSE=103759834.926579

# %%
residuals = timeseries.best_model(train,test, order=(2,1,1), lags=10)
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6154      0.086      7.188      0.000       0.448       0.783
# ar.L2          0.0409      0.094      0.437      0.662      -0.143       0.224
# ma.L1         -0.9370      0.055    -17.011      0.000      -1.045      -0.829
# sigma2       2.58e+07   4.96e-10   5.21e+16      0.000    2.58e+07    2.58e+07
# ==============================================================================
#
#
# -----------------------------------------------
#  -----------------------------------------------
#
# Ljung-Box Test - Checks for Serial Correlation
#
# null-hypothesis:         The residuals are independently distributed.
# alternative-hypothesis:  The residuals are not independently distributed
#  -----------------------------------------------
#       lb_stat  lb_pvalue
# 1    0.016127   0.898947
# 2    0.086815   0.957521
# 3    0.198749   0.977791
# 4    2.819700   0.588437
# 5    3.959217   0.555303
# 6    4.049535   0.669973
# 7    7.745403   0.355579
# 8    7.900848   0.443215
# 9   11.282924   0.256813
# 10  12.273580   0.267164
#
#
# -----------------------------------------------
#  -----------------------------------------------
#
# How predictions compares to actual test data

# %%
predictions = timeseries.forecasts(data["Volume Horticulture  (Tonnes)"],order=(2,1,1),steps=20)

# %%
from basicTimeSeries import SARIMAModels

# %%
sarima_models = SARIMAModels()
sarima_models.model_evaluation(train_data=train, order_limit=2)
# Out:
# Choosing the best model from the range provided
#  -----------------------------------------------
# ARIMA(0, 0, 0)x(0, 0, 0, 12)season:12 - AIC:3787.6179432123718 - LLF:-1892.8089716061859
# ARIMA(0, 0, 0)x(0, 0, 1, 12)season:12 - AIC:3432.6198058538175 - LLF:-1714.3099029269088
# ARIMA(0, 0, 0)x(0, 1, 0, 12)season:12 - AIC:3146.2565356085706 - LLF:-1572.1282678042853
# ARIMA(0, 0, 0)x(0, 1, 1, 12)season:12 - AIC:2858.292934264693 - LLF:-1427.1464671323465
# ARIMA(0, 0, 0)x(1, 0, 0, 12)season:12 - AIC:3168.351812197443 - LLF:-1582.1759060987215
# ARIMA(0, 0, 0)x(1, 0, 1, 12)season:12 - AIC:3101.4208598382966 - LLF:-1547.7104299191483
# ARIMA(0, 0, 0)x(1, 1, 0, 12)season:12 - AIC:2858.6450321413577 - LLF:-1427.3225160706788
# ARIMA(0, 0, 0)x(1, 1, 1, 12)season:12 - AIC:2834.1301686581273 - LLF:-1414.0650843290637
# ARIMA(0, 0, 1)x(0, 0, 0, 12)season:12 - AIC:3656.844015512756 - LLF:-1826.422007756378
# ARIMA(0, 0, 1)x(0, 0, 1, 12)season:12 - AIC:3362.014277656281 - LLF:-1678.0071388281406
# ARIMA(0, 0, 1)x(0, 1, 0, 12)season:12 - AIC:3059.4144108155924 - LLF:-1527.7072054077962
# ARIMA(0, 0, 1)x(0, 1, 1, 12)season:12 - AIC:2780.220217848537 - LLF:-1387.1101089242684
# ARIMA(0, 0, 1)x(1, 0, 0, 12)season:12 - AIC:3390.202858310443 - LLF:-1692.1014291552215
# ARIMA(0, 0, 1)x(1, 0, 1, 12)season:12 - AIC:3344.7880834620973 - LLF:-1668.3940417310487
# ARIMA(0, 0, 1)x(1, 1, 0, 12)season:12 - AIC:2820.1147116911716 - LLF:-1407.0573558455858
# ARIMA(0, 0, 1)x(1, 1, 1, 12)season:12 - AIC:2777.9619155841824 - LLF:-1384.9809577920912
# ARIMA(0, 1, 0)x(0, 0, 0, 12)season:12 - AIC:3198.211166947979 - LLF:-1598.1055834739896
# ARIMA(0, 1, 0)x(0, 0, 1, 12)season:12 - AIC:2936.7663725178645 - LLF:-1466.3831862589323
# ARIMA(0, 1, 0)x(0, 1, 0, 12)season:12 - AIC:3038.0230437941937 - LLF:-1518.0115218970968
# ARIMA(0, 1, 0)x(0, 1, 1, 12)season:12 - AIC:2712.929944359139 - LLF:-1354.4649721795695
# ARIMA(0, 1, 0)x(1, 0, 0, 12)season:12 - AIC:2954.509323168017 - LLF:-1475.2546615840085
# ARIMA(0, 1, 0)x(1, 0, 1, 12)season:12 - AIC:2938.2369186493383 - LLF:-1466.1184593246692
# ARIMA(0, 1, 0)x(1, 1, 0, 12)season:12 - AIC:2764.825400337608 - LLF:-1380.412700168804
# ARIMA(0, 1, 0)x(1, 1, 1, 12)season:12 - AIC:2713.0057623332204 - LLF:-1353.5028811666102
# ARIMA(0, 1, 1)x(0, 0, 0, 12)season:12 - AIC:3168.3274585654085 - LLF:-1582.1637292827043
# ARIMA(0, 1, 1)x(0, 0, 1, 12)season:12 - AIC:2915.497163143984 - LLF:-1454.748581571992
# ARIMA(0, 1, 1)x(0, 1, 0, 12)season:12 - AIC:3013.7210840788775 - LLF:-1504.8605420394388
# ARIMA(0, 1, 1)x(0, 1, 1, 12)season:12 - AIC:2707.2918913577296 - LLF:-1350.6459456788648
# ARIMA(0, 1, 1)x(1, 0, 0, 12)season:12 - AIC:2951.820853934544 - LLF:-1472.910426967272
# ARIMA(0, 1, 1)x(1, 0, 1, 12)season:12 - AIC:2915.3635465816196 - LLF:-1453.6817732908098
# ARIMA(0, 1, 1)x(1, 1, 0, 12)season:12 - AIC:2769.805807210443 - LLF:-1381.9029036052216
# ARIMA(0, 1, 1)x(1, 1, 1, 12)season:12 - AIC:2685.6037657523457 - LLF:-1338.8018828761728
# ARIMA(1, 0, 0)x(0, 0, 0, 12)season:12 - AIC:3218.604383549883 - LLF:-1607.3021917749415
# ARIMA(1, 0, 0)x(0, 0, 1, 12)season:12 - AIC:2957.879520793554 - LLF:-1475.939760396777
# ARIMA(1, 0, 0)x(0, 1, 0, 12)season:12 - AIC:3037.061795459792 - LLF:-1516.530897729896
# ARIMA(1, 0, 0)x(0, 1, 1, 12)season:12 - AIC:2742.011819961138 - LLF:-1368.005909980569
# ARIMA(1, 0, 0)x(1, 0, 0, 12)season:12 - AIC:2957.8095854800213 - LLF:-1475.9047927400106
# ARIMA(1, 0, 0)x(1, 0, 1, 12)season:12 - AIC:2959.7051177537915 - LLF:-1475.8525588768957
# ARIMA(1, 0, 0)x(1, 1, 0, 12)season:12 - AIC:2754.0368991549685 - LLF:-1374.0184495774843
# ARIMA(1, 0, 0)x(1, 1, 1, 12)season:12 - AIC:2743.852446868873 - LLF:-1367.9262234344365
# ARIMA(1, 0, 1)x(0, 0, 0, 12)season:12 - AIC:3190.7648255126483 - LLF:-1592.3824127563241
# ARIMA(1, 0, 1)x(0, 0, 1, 12)season:12 - AIC:2936.2649014860494 - LLF:-1464.1324507430247
# ARIMA(1, 0, 1)x(0, 1, 0, 12)season:12 - AIC:3019.2589831311943 - LLF:-1506.6294915655972
# ARIMA(1, 0, 1)x(0, 1, 1, 12)season:12 - AIC:2722.4176282525887 - LLF:-1357.2088141262943
# ARIMA(1, 0, 1)x(1, 0, 0, 12)season:12 - AIC:2955.0810732523137 - LLF:-1473.5405366261568
# ARIMA(1, 0, 1)x(1, 0, 1, 12)season:12 - AIC:2937.422100057988 - LLF:-1463.711050028994
# ARIMA(1, 0, 1)x(1, 1, 0, 12)season:12 - AIC:2748.189593947961 - LLF:-1370.0947969739805
# ARIMA(1, 0, 1)x(1, 1, 1, 12)season:12 - AIC:2724.0717293130697 - LLF:-1357.0358646565348
# ARIMA(1, 1, 0)x(0, 0, 0, 12)season:12 - AIC:3192.229030759886 - LLF:-1594.114515379943
# ARIMA(1, 1, 0)x(0, 0, 1, 12)season:12 - AIC:2934.1776074995555 - LLF:-1464.0888037497778
# ARIMA(1, 1, 0)x(0, 1, 0, 12)season:12 - AIC:3034.3332814641617 - LLF:-1515.1666407320809
# ARIMA(1, 1, 0)x(0, 1, 1, 12)season:12 - AIC:2727.261216755381 - LLF:-1360.6306083776906
# ARIMA(1, 1, 0)x(1, 0, 0, 12)season:12 - AIC:2934.089333435299 - LLF:-1464.0446667176495
# ARIMA(1, 1, 0)x(1, 0, 1, 12)season:12 - AIC:2936.7774258125232 - LLF:-1464.3887129062616
# ARIMA(1, 1, 0)x(1, 1, 0, 12)season:12 - AIC:2750.9970732461525 - LLF:-1372.4985366230762
# ARIMA(1, 1, 0)x(1, 1, 1, 12)season:12 - AIC:2706.5892571417553 - LLF:-1349.2946285708776
# ARIMA(1, 1, 1)x(0, 0, 0, 12)season:12 - AIC:3159.0101239476908 - LLF:-1576.5050619738454
# ARIMA(1, 1, 1)x(0, 0, 1, 12)season:12 - AIC:2906.6949975184507 - LLF:-1449.3474987592253
# ARIMA(1, 1, 1)x(0, 1, 0, 12)season:12 - AIC:3009.938176493984 - LLF:-1501.969088246992
# ARIMA(1, 1, 1)x(0, 1, 1, 12)season:12 - AIC:2703.682153068761 - LLF:-1347.8410765343806
# ARIMA(1, 1, 1)x(1, 0, 0, 12)season:12 - AIC:2925.7317204852625 - LLF:-1458.8658602426312
# ARIMA(1, 1, 1)x(1, 0, 1, 12)season:12 - AIC:2908.535052574467 - LLF:-1449.2675262872335
# ARIMA(1, 1, 1)x(1, 1, 0, 12)season:12 - AIC:2744.553331130973 - LLF:-1368.2766655654866
# ARIMA(1, 1, 1)x(1, 1, 1, 12)season:12 - AIC:2705.60842439303 - LLF:-1347.804212196515
# Best Order(0, 1, 1) Seasonal_order(1, 1, 1, 12) AIC=2685.604

# %%
residuals = sarima_models.best_model(train, test, order=(0, 1, 1),
                         seasonal_order=(1, 1, 1, 12), lags=10)
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.2836      0.091     -3.104      0.002      -0.463      -0.105
# ar.S.L12      -0.0363      0.088     -0.412      0.681      -0.209       0.137
# ma.S.L12      -0.8613      0.050    -17.206      0.000      -0.959      -0.763
# sigma2      2.374e+07   3.35e-10   7.09e+16      0.000    2.37e+07    2.37e+07
# ==============================================================================
#
#
# -----------------------------------------------
#  -----------------------------------------------
#
# Ljung-Box Test - Checks for Serial Correlation
#
# null-hypothesis:         The residuals are independently distributed.
# alternative-hypothesis:  The residuals are not independently distributed
#  -----------------------------------------------
#       lb_stat  lb_pvalue
# 1    0.027218   0.868960
# 2    0.674712   0.713655
# 3    1.433285   0.697752
# 4    7.427588   0.114945
# 5    7.427592   0.190732
# 6    7.580720   0.270457
# 7   13.760083   0.055617
# 8   14.145434   0.078053
# 9   15.777653   0.071672
# 10  17.480553   0.064384
#
#
# -----------------------------------------------
#  -----------------------------------------------
#
# How predictions compares to actual test data

# %%
predictions = sarima_models.forecasts(data["Volume Horticulture  (Tonnes)"],
                                      order=(0, 1, 1),seasonal_order=(1, 1, 1, 12),
                                      steps=20)
