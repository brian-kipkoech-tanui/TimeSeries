# %%
from basicTimeSeries import TimeSeries

# %%
import pandas as pd
data = pd.read_excel(r"C:\Users\HP\Desktop\data\US\gands.xlsx")
data.set_index("Period", inplace=True)

# %%
timeseries = TimeSeries() 
timeseries.visualizations(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 timeseries = TimeSeries()
# ----> 2 timeseries.visualizations(data)
#
# File ~\Desktop\clean-timeseries\BasicTimeSeriesModels\basicTimeSeries.py:36, in TimeSeries.visualizations(self, data)
#      34 for i in range(len(list(data.columns))):
#      35     df = list(data.columns)[i]
# ---> 36     data[df].plot(figsize=(12, 5), color = "white") # Plotting the time series plots
#      37     plt.title(df, size=14)
#      38     plt.show()
#
# File C:\Python310\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# ...
